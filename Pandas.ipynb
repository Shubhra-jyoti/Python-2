# %%
import pandas as pd
import numpy as np

# %%
# Series
ds=pd.Series([10,20,30,40])
ds
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# index change
ds=pd.Series([10,20,30,40],index=[1,2,3,4])
ds
# Out:
# 1    10
# 2    20
# 3    30
# 4    40
# dtype: int64

# %%
ds=pd.Series({"B":1,"H":2,"A":3})
ds
# Out:
# B    1
# H    2
# A    3
# dtype: int64

# %%
ds=pd.Series(np.arange(75,100))
ds
# Out:
# 0     75
# 1     76
# 2     77
# 3     78
# 4     79
# 5     80
# 6     81
# 7     82
# 8     83
# 9     84
# 10    85
# 11    86
# 12    87
# 13    88
# 14    89
# 15    90
# 16    91
# 17    92
# 18    93
# 19    94
# 20    95
# 21    96
# 22    97
# 23    98
# 24    99
# dtype: int32

# %%
type(ds)
# Out:
# pandas.core.series.Series

# %%
# DataFrame
df=pd.DataFrame([["hey","jude","i"],["love","music","tune"]],index=["a","b"],columns=["p","q","r"])
df
# Out:
#       p      q     r
# a   hey   jude     i
# b  love  music  tune

# %%
df=pd.DataFrame({
    "p":[1,2,3,4],
    "q":[5,6,7,8]
})
df
# Out:
#    p  q
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
df=pd.DataFrame({
    "p":[1,2,3,4],
    "q":[5,6,7,8]
},columns=["x","y"])
df
# Out:
# Empty DataFrame
# Columns: [x, y]
# Index: []

# %%
df=pd.DataFrame(np.array([[1,2,3,4],[5,7,8,9]]))
df
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  7  8  9

# %%
df=pd.DataFrame([
    {
         "p":[1,2,3,4],
        "q":[5,6,7,8]
    },
    {
       "a":["t","p","m","n"],
        "b":["l","g","b","t"]
    }
])
df
# Out:
#               p             q             a             b
# 0  [1, 2, 3, 4]  [5, 6, 7, 8]           NaN           NaN
# 1           NaN           NaN  [t, p, m, n]  [l, g, b, t]

# %%
df=pd.DataFrame([
    {
         "p":[1,2,3,4],
        "q":[5,6,7,8]
    },
    {
       "p":["t","p","m","n"],
        "q":["l","g","b","t"]
    }
])
df
# Out:
#               p             q
# 0  [1, 2, 3, 4]  [5, 6, 7, 8]
# 1  [t, p, m, n]  [l, g, b, t]

# %%
df=pd.read_csv("../Datasets/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.size
# Out:
# 10692

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.T
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
df["Pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
type(df["Pclass"])
# Out:
# pandas.core.series.Series

# %%
df[["Pclass","Age"]]
# Out:
#      Pclass   Age
# 0         3  22.0
# 1         1  38.0
# 2         3  26.0
# 3         1  35.0
# 4         3  35.0
# ..      ...   ...
# 886       2  27.0
# 887       1  19.0
# 888       3   NaN
# 889       1  26.0
# 890       3  32.0
#
# [891 rows x 2 columns]

# %%
df["Age"]>18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df[df["Age"]>18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df["Sex"]=="male") & (df["Age"]>18)]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# 13            14         0       3     Andersson, Mr. Anders Johan  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
malesurvived=df[(df["Sex"]=="male") & (df["Survived"]==1)]
femalesurvived=df[(df["Sex"]=="female") & (df["Survived"]==1)]
print("males=",malesurvived.shape[0])
print("females=",femalesurvived.shape[0])
# Out:
# males= 109
# females= 233

# %%
df.iloc[2,2]
# Out:
# 3

# %%
df.iloc[:,3]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.iloc[:10,3:9]
# Out:
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket
# 0      0         A/5 21171
# 1      0          PC 17599
# 2      0  STON/O2. 3101282
# 3      0            113803
# ...

# %%
df=pd.DataFrame({
    "sub":["Python","FSD","COA","TOC","DM"],
    "faculty":["VHA","PSP","VBY","DPS","MSS"],
    "marks":[10,9,10,9,9]
})
df
# Out:
#       sub faculty  marks
# 0  Python     VHA     10
# 1     FSD     PSP      9
# 2     COA     VBY     10
# 3     TOC     DPS      9
# 4      DM     MSS      9

# %%
df.set_index("sub",drop=False)
# Out:
#            sub faculty  marks
# sub
# Python  Python     VHA     10
# FSD        FSD     PSP      9
# COA        COA     VBY     10
# TOC        TOC     DPS      9
# DM          DM     MSS      9

# %%
df=df.set_index("sub",drop=True)
df
# Out:
#        faculty  marks
# sub
# Python     VHA     10
# FSD        PSP      9
# COA        VBY     10
# TOC        DPS      9
# DM         MSS      9

# %%
df=df.reset_index()
df
# Out:
#       sub faculty  marks
# 0  Python     VHA     10
# 1     FSD     PSP      9
# 2     COA     VBY     10
# 3     TOC     DPS      9
# 4      DM     MSS      9

# %%
df=pd.read_csv("../Datasets/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=df.set_index("Name")
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.loc["Futrelle, Mrs. Jacques Heath (Lily May Peel)"]
# Out:
# PassengerId         4
# Survived            1
# Pclass              1
# Sex            female
# Age              35.0
# SibSp               1
# Parch               0
# Ticket         113803
# Fare             53.1
# Cabin            C123
# Embarked            S
# Name: Futrelle, Mrs. Jacques Heath (Lily May Peel), dtype: object

# %%
df=pd.DataFrame({
    "sub":["Python","FSD","COA","TOC","DM"],
    "faculty":["VHA","PSP","VBY","DPS","MSS"],
    "marks":[10,9,10,9,9]
})
df
# Out:
#       sub faculty  marks
# 0  Python     VHA     10
# 1     FSD     PSP      9
# 2     COA     VBY     10
# 3     TOC     DPS      9
# 4      DM     MSS      9

# %%
df=df.set_index("sub")
df
# Out:
#        faculty  marks
# sub
# Python     VHA     10
# FSD        PSP      9
# COA        VBY     10
# TOC        DPS      9
# DM         MSS      9

# %%
df.loc["FSD","faculty"]
# Out:
# 'PSP'

# %%
df.loc["FSD","faculty"]="NAS"
df
# Out:
#        faculty  marks
# sub
# Python     VHA     10
# FSD        NAS      9
# COA        VBY     10
# TOC        DPS      9
# DM         MSS      9

# %%
df.loc["FSD","marks"]=10
df
# Out:
#        faculty  marks
# sub
# Python     VHA     10
# FSD        NAS     10
# COA        VBY     10
# TOC        DPS      9
# DM         MSS      9

# %%
df.loc["project"]=["VHA",10]
df
# Out:
#         faculty  marks
# sub
# Python      VHA     10
# FSD         NAS     10
# COA         VBY     10
# TOC         DPS      9
# DM          MSS      9
# project     VHA     10

# %%
df["HOD"]="MJT"
df
# Out:
#         faculty  marks  HOD
# sub
# Python      VHA     10  MJT
# FSD         NAS     10  MJT
# COA         VBY     10  MJT
# TOC         DPS      9  MJT
# DM          MSS      9  MJT
# project     VHA     10  MJT

# %%
arr=np.random.rand(8,5)
arr
# Out:
# array([[0.63638137, 0.51998527, 0.33158005, 0.45466507, 0.7524756 ],
#        [0.8198621 , 0.15137968, 0.1609941 , 0.38357677, 0.21338725],
#        [0.2756909 , 0.48281022, 0.64925783, 0.7005481 , 0.63191227],
#        [0.84036213, 0.20793796, 0.80725632, 0.87663525, 0.62654196],
#        [0.26898632, 0.80707423, 0.59096899, 0.97714861, 0.15591537],
#        [0.54842548, 0.46661891, 0.87679235, 0.16782886, 0.52028098],
#        [0.68472472, 0.06248183, 0.95335702, 0.58579049, 0.99926368],
#        [0.71955612, 0.51459719, 0.60913155, 0.58949759, 0.61880862]])

# %%
df=pd.DataFrame(arr,columns=["A","B","C","D","E"])
df
# Out:
#           A         B         C         D         E
# 0  0.636381  0.519985  0.331580  0.454665  0.752476
# 1  0.819862  0.151380  0.160994  0.383577  0.213387
# 2  0.275691  0.482810  0.649258  0.700548  0.631912
# 3  0.840362  0.207938  0.807256  0.876635  0.626542
# 4  0.268986  0.807074  0.590969  0.977149  0.155915
# 5  0.548425  0.466619  0.876792  0.167829  0.520281
# 6  0.684725  0.062482  0.953357  0.585790  0.999264
# 7  0.719556  0.514597  0.609132  0.589498  0.618809

# %%
print("shape:",df.shape)
print("size:",df.size)
print("dim:",df.ndim)
# Out:
# shape: (8, 5)
# size: 40
# dim: 2

# %%
df["sum"]=df["A"]+df["B"]+df["C"]+df["D"]+df["E"]
df
# Out:
#           A         B         C         D         E       sum
# 0  0.636381  0.519985  0.331580  0.454665  0.752476  2.695087
# 1  0.819862  0.151380  0.160994  0.383577  0.213387  1.729200
# 2  0.275691  0.482810  0.649258  0.700548  0.631912  2.740219
# 3  0.840362  0.207938  0.807256  0.876635  0.626542  3.358734
# 4  0.268986  0.807074  0.590969  0.977149  0.155915  2.800094
# 5  0.548425  0.466619  0.876792  0.167829  0.520281  2.579947
# 6  0.684725  0.062482  0.953357  0.585790  0.999264  3.285618
# 7  0.719556  0.514597  0.609132  0.589498  0.618809  3.051591

# %%
df.iloc[5,2]=699
df
# Out:
#           A         B           C         D         E       sum
# 0  0.636381  0.519985    0.331580  0.454665  0.752476  2.695087
# 1  0.819862  0.151380    0.160994  0.383577  0.213387  1.729200
# 2  0.275691  0.482810    0.649258  0.700548  0.631912  2.740219
# 3  0.840362  0.207938    0.807256  0.876635  0.626542  3.358734
# 4  0.268986  0.807074    0.590969  0.977149  0.155915  2.800094
# 5  0.548425  0.466619  699.000000  0.167829  0.520281  2.579947
# 6  0.684725  0.062482    0.953357  0.585790  0.999264  3.285618
# 7  0.719556  0.514597    0.609132  0.589498  0.618809  3.051591

# %%
df.iloc[1:7,1:4]
# Out:
#           B           C         D
# 1  0.151380    0.160994  0.383577
# 2  0.482810    0.649258  0.700548
# 3  0.207938    0.807256  0.876635
# 4  0.807074    0.590969  0.977149
# 5  0.466619  699.000000  0.167829
# 6  0.062482    0.953357  0.585790

# %%
df.loc[7]=[1,2,3,4,5,90]
df
# Out:
#           A         B           C         D         E        sum
# 0  0.636381  0.519985    0.331580  0.454665  0.752476   2.695087
# 1  0.819862  0.151380    0.160994  0.383577  0.213387   1.729200
# 2  0.275691  0.482810    0.649258  0.700548  0.631912   2.740219
# 3  0.840362  0.207938    0.807256  0.876635  0.626542   3.358734
# 4  0.268986  0.807074    0.590969  0.977149  0.155915   2.800094
# 5  0.548425  0.466619  699.000000  0.167829  0.520281   2.579947
# 6  0.684725  0.062482    0.953357  0.585790  0.999264   3.285618
# 7  1.000000  2.000000    3.000000  4.000000  5.000000  90.000000

# %%
arr=np.random.rand(5,4)
df=pd.DataFrame(arr,columns=["CourseID","CourseName","Credits","Faculty"])
df
# Out:
#    CourseID  CourseName   Credits   Faculty
# 0  0.571082    0.760637  0.358122  0.782660
# 1  0.422703    0.775862  0.324835  0.693031
# 2  0.358262    0.133635  0.566039  0.051363
# 3  0.739411    0.234380  0.406210  0.977359
# 4  0.840617    0.637739  0.802656  0.275279

# %%
df.set_index("CourseID",inplace=True)
df
# Out:
#           CourseName   Credits   Faculty
# CourseID
# 0.571082    0.760637  0.358122  0.782660
# 0.422703    0.775862  0.324835  0.693031
# 0.358262    0.133635  0.566039  0.051363
# 0.739411    0.234380  0.406210  0.977359
# 0.840617    0.637739  0.802656  0.275279

# %%
df["Semester"]=1
df
# Out:
#           CourseName   Credits   Faculty  Semester
# CourseID
# 0.571082    0.760637  0.358122  0.782660         1
# 0.422703    0.775862  0.324835  0.693031         1
# 0.358262    0.133635  0.566039  0.051363         1
# 0.739411    0.234380  0.406210  0.977359         1
# 0.840617    0.637739  0.802656  0.275279         1

# %%
df.iloc[1,1]=44
df
# Out:
#           CourseName    Credits   Faculty  Semester
# CourseID
# 0.571082    0.760637   0.358122  0.782660         1
# 0.422703    0.775862  44.000000  0.693031         1
# 0.358262    0.133635   0.566039  0.051363         1
# 0.739411    0.234380   0.406210  0.977359         1
# 0.840617    0.637739   0.802656  0.275279         1

# %%
df.loc[69]=[1,2,3,4]
df
# Out:
#            CourseName    Credits   Faculty  Semester
# CourseID
# 0.571082     0.760637   0.358122  0.782660         1
# 0.422703     0.775862  44.000000  0.693031         1
# 0.358262     0.133635   0.566039  0.051363         1
# 0.739411     0.234380   0.406210  0.977359         1
# 0.840617     0.637739   0.802656  0.275279         1
# 69.000000    1.000000   2.000000  3.000000         4

# %%
train_df=pd.read_csv("../Datasets/train.csv")
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.head(8)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
train_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train_df.sample(9)
# Out:
#      PassengerId  Survived  Pclass  \
# 659          660         0       1
# 373          374         0       1
# 1              2         1       1
# 387          388         1       2
# 154          155         0       3
# 261          262         1       3
# 112          113         0       3
# 299          300         1       1
# 158          159         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 659                         Newell, Mr. Arthur Webster    male  58.0      0
# 373                                Ringhini, Mr. Sante    male  22.0      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 387                                   Buss, Miss. Kate  female  36.0      0
# 154                              Olsen, Mr. Ole Martin    male   NaN      0
# 261                  Asplund, Master. Edvin Rojj Felix    male   3.0      4
# ...

# %%
train_df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
train_df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
train_df.describe(include="object")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
train_df.describe(exclude="int")
# Out:
#                            Name   Sex         Age  Ticket        Fare  \
# count                       891   891  714.000000     891  891.000000
# unique                      891     2         NaN     681         NaN
# top     Braund, Mr. Owen Harris  male         NaN  347082         NaN
# freq                          1   577         NaN       7         NaN
# mean                        NaN   NaN   29.699118     NaN   32.204208
# std                         NaN   NaN   14.526497     NaN   49.693429
# min                         NaN   NaN    0.420000     NaN    0.000000
# 25%                         NaN   NaN   20.125000     NaN    7.910400
# 50%                         NaN   NaN   28.000000     NaN   14.454200
# 75%                         NaN   NaN   38.000000     NaN   31.000000
# max                         NaN   NaN   80.000000     NaN  512.329200
#
#           Cabin Embarked
# count       204      889
# unique      147        3
# top     B96 B98        S
# ...

# %%
df=pd.DataFrame([[1,np.nan,3,4],[2,4,np.nan,8],[np.nan,4,5,9],[np.nan,1,np.nan,3],[np.nan,np.nan,np.nan,9],[1,1,1,1]],columns=["A","B","C","D"])
df
# Out:
#      A    B    C  D
# 0  1.0  NaN  3.0  4
# 1  2.0  4.0  NaN  8
# 2  NaN  4.0  5.0  9
# 3  NaN  1.0  NaN  3
# 4  NaN  NaN  NaN  9
# 5  1.0  1.0  1.0  1

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False   True  False  False
# 1  False  False   True  False
# 2   True  False  False  False
# 3   True  False   True  False
# 4   True   True   True  False
# 5  False  False  False  False

# %%
df.isna().sum()
# Out:
# A    3
# B    2
# C    3
# D    0
# dtype: int64

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(axis=0)#by default how="any"
# Out:
#      A    B    C  D
# 5  1.0  1.0  1.0  1

# %%
df.dropna(axis=1)
# Out:
#    D
# 0  4
# 1  8
# 2  9
# 3  3
# 4  9
# 5  1

# %%
df.dropna(how="all")#will drop a row that contains all NaN
# Out:
#      A    B    C  D
# 0  1.0  NaN  3.0  4
# 1  2.0  4.0  NaN  8
# 2  NaN  4.0  5.0  9
# 3  NaN  1.0  NaN  3
# 4  NaN  NaN  NaN  9
# 5  1.0  1.0  1.0  1

# %%
df.dropna(subset=["A"])
# Out:
#      A    B    C  D
# 0  1.0  NaN  3.0  4
# 1  2.0  4.0  NaN  8
# 5  1.0  1.0  1.0  1

# %%
df.dropna(subset=["B","C"])#will drop any row that contains NaN in B and C column
# Out:
#      A    B    C  D
# 2  NaN  4.0  5.0  9
# 5  1.0  1.0  1.0  1

# %%
df.dropna(subset=["B","C"],how="all")#will drop rows that contains NaN in both B and C together
# Out:
#      A    B    C  D
# 0  1.0  NaN  3.0  4
# 1  2.0  4.0  NaN  8
# 2  NaN  4.0  5.0  9
# 3  NaN  1.0  NaN  3
# 5  1.0  1.0  1.0  1

# %%
df.dropna(thresh=3)#a row must have more than three non NaN values
# Out:
#      A    B    C  D
# 0  1.0  NaN  3.0  4
# 1  2.0  4.0  NaN  8
# 2  NaN  4.0  5.0  9
# 5  1.0  1.0  1.0  1

# %%
train_df.dropna(subset=["Cabin"])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["A"]=df["A"].fillna(df["A"].mean())

# %%
df
# Out:
#           A    B    C  D
# 0  1.000000  NaN  3.0  4
# 1  2.000000  4.0  NaN  8
# 2  1.333333  4.0  5.0  9
# 3  1.333333  1.0  NaN  3
# 4  1.333333  NaN  NaN  9
# 5  1.000000  1.0  1.0  1

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df["Age"]=train_df["Age"].fillna(train_df.Age.mean())

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             89
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
train_df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
train_df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
train_df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train_df["Embarked"]=train_df["Embarked"].fillna(train_df.Embarked.mode()[0])

# %%
train_df.Embarked.value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df=pd.DataFrame([[1,2,3,4],[4,5,6,7],[1,2,3,4],[1,2,5,6]])
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df.drop_duplicates(keep=False,subset=[0])
# Out:
#    0  1  2  3
# 1  4  5  6  7

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.duplicated(subset=[1,2]).sum()
# Out:
# 2

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.duplicated(subset=["Sex"]).sum()
# Out:
# 889

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.drop("Cabin",axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ind=df[df["Sex"]=="male"].index
ind

# df=df.drop(ind,axis=0)
# df
# Out:
# Int64Index([  0,   4,   5,   6,   7,  12,  13,  16,  17,  20,
#             ...
#             873, 876, 877, 878, 881, 883, 884, 886, 889, 890],
#            dtype='int64', length=577)

# %%
df[(df["Sex"]=="male")&(df["Survived"]==1)]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
df.sort_values("Age",ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values(["Age","Name"],ascending=[False,True])
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 55            56         1       1                     Woolner, Mr. Hugh
# 354          355         0       3                     Yousif, Mr. Wazli
# 495          496         0       3                 Yousseff, Mr. Gerious
# 240          241         0       3                 Zabour, Miss. Thamine
# 868          869         0       3           van Melkebeke, Mr. Philemon
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
ds=df.set_index("Name")
ds.sort_index(axis=0)
# Out:
#                                        PassengerId  Survived  Pclass     Sex  \
# Name
# Abbing, Mr. Anthony                            846         0       3    male
# Abbott, Mr. Rossmore Edward                    747         0       3    male
# Abbott, Mrs. Stanton (Rosa Hunt)               280         1       3  female
# Abelson, Mr. Samuel                            309         0       2    male
# Abelson, Mrs. Samuel (Hannah Wizosky)          875         1       2  female
# ...                                            ...       ...     ...     ...
# de Mulder, Mr. Theodore                        287         1       3    male
# de Pelsmaeker, Mr. Alfons                      283         0       3    male
# del Carlo, Mr. Sebastiano                      362         0       2    male
# van Billiard, Mr. Austin Blyler                154         0       3    male
# van Melkebeke, Mr. Philemon                    869         0       3    male
#
# ...

# %%
ds.sort_index(axis=1)
# Out:
#                                                      Age Cabin Embarked  \
# Name
# Braund, Mr. Owen Harris                             22.0   NaN        S
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  38.0   C85        C
# Heikkinen, Miss. Laina                              26.0   NaN        S
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        35.0  C123        S
# Allen, Mr. William Henry                            35.0   NaN        S
# ...                                                  ...   ...      ...
# Montvila, Rev. Juozas                               27.0   NaN        S
# Graham, Miss. Margaret Edith                        19.0   B42        S
# Johnston, Miss. Catherine Helen "Carrie"             NaN   NaN        S
# Behr, Mr. Karl Howell                               26.0  C148        C
# Dooley, Mr. Patrick                                 32.0   NaN        Q
#
#                                                        Fare  Parch  \
# Name
# ...

# %%
df.sum(axis=0)
# Out:
# <ipython-input-55-3e0711333bf9>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum(axis=0)
# PassengerId                                               397386
# Survived                                                     342
# Pclass                                                      2057
# Name           Braund, Mr. Owen HarrisCumings, Mrs. John Brad...
# Sex            malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                     21205.17
# SibSp                                                        466
# Parch                                                        340
# Ticket         A/5 21171PC 17599STON/O2. 31012821138033734503...
# Fare                                                  28693.9493
# dtype: object

# %%
df.corr()#future updates will use numeric_only=True
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='PassengerId', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Survived', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Age', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Parch', ylabel='PassengerId'>,
#         <AxesSubplot:xlabel='Fare', ylabel='PassengerId'>],
#        [<AxesSubplot:xlabel='PassengerId', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Survived', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Pclass', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Age', ylabel='Survived'>,
#         <AxesSubplot:xlabel='SibSp', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Parch', ylabel='Survived'>,
#         <AxesSubplot:xlabel='Fare', ylabel='Survived'>],
#        [<AxesSubplot:xlabel='PassengerId', ylabel='Pclass'>,
#         <AxesSubplot:xlabel='Survived', ylabel='Pclass'>,
# ...

# %%
pd.crosstab(df["Survived"],df["Pclass"],margins=True)
# Out:
# Pclass      1    2    3  All
# Survived
# 0          80   97  372  549
# 1         136   87  119  342
# All       216  184  491  891

# %%
pd.plotting.parallel_coordinates(df,"Sex",["Pclass","Survived","Parch"])
# Out:
# <AxesSubplot:>

# %%
df=pd.read_csv("../Datasets/auto-mpg.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
ind=df[df["horsepower"]=="?"].index
ind
# Out:
# Int64Index([32, 126, 330, 336, 354, 374], dtype='int64')

# %%
ds=df.drop(ind,axis=0)
ds
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
mean=ds["horsepower"].astype("int").mean()

# %%
df["horsepower"]=df["horsepower"].replace("?",mean)

# %%
df.horsepower.unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', 104.46938775510205, '100', '105', '175',
#        '153', '180', '110', '72', '86', '70', '76', '65', '69', '60',
#        '80', '54', '208', '155', '112', '92', '145', '137', '158', '167',
#        '94', '107', '230', '49', '75', '91', '122', '67', '83', '78',
#        '52', '61', '93', '148', '129', '96', '71', '98', '115', '53',
#        '81', '79', '120', '152', '102', '108', '68', '58', '149', '89',
#        '63', '48', '66', '139', '103', '125', '133', '138', '135', '142',
#        '77', '62', '132', '84', '64', '74', '116', '82'], dtype=object)

# %%
df["horsepower"]=df["horsepower"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    int32
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int32(1), int64(4), object(1)
# memory usage: 26.6+ KB

# %%
df.horsepower.unique()
# Out:
# array([130, 165, 150, 140, 198, 220, 215, 225, 190, 170, 160,  95,  97,
#         85,  88,  46,  87,  90, 113, 200, 210, 193, 104, 100, 105, 175,
#        153, 180, 110,  72,  86,  70,  76,  65,  69,  60,  80,  54, 208,
#        155, 112,  92, 145, 137, 158, 167,  94, 107, 230,  49,  75,  91,
#        122,  67,  83,  78,  52,  61,  93, 148, 129,  96,  71,  98, 115,
#         53,  81,  79, 120, 152, 102, 108,  68,  58, 149,  89,  63,  48,
#         66, 139, 103, 125, 133, 138, 135, 142,  77,  62, 132,  84,  64,
#         74, 116,  82])

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       94
# weight          351
# acceleration     95
# model year       13
# origin            3
# car name        305
# dtype: int64

# %%
pd.plotting.parallel_coordinates(df,"cylinders",["horsepower","weight","mpg"])
# Out:
# <Axes: >

# %%
pip install --upgrade seaborn --user
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# mlxtend 0.23.1 requires scikit-learn>=1.0.2, but you'll have scikit-learn 0.23.2 which is incompatible.
# ...

# %%
import seaborn as sns


sns.boxenplot(x="mpg",hue='cylinders',data=df)
# Out:
# <Axes: xlabel='mpg'>

# %%
sns.boxenplot(x="mpg",data=df)
# Out:
# <Axes: xlabel='mpg'>

# %%
q1=df.mpg.quantile(0.25)
q1
q3=df.mpg.quantile(0.75)

# %%
df.mpg.describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
iqr=q3-q1
iqr
# Out:
# 11.5

# %%
hl=q3+1.5*iqr
ll=q1-1.5*iqr

# %%
hl,ll
# Out:
# (46.25, 0.25)

# %%
wo=df[(df["mpg"]<hl) &(df["mpg"]>ll)]
sns.boxenplot(x="mpg",data=wo)
# Out:
# <Axes: xlabel='mpg'>

# %%
q1=df.horsepower.quantile(0.25)
q1
q3=df.horsepower.quantile(0.75)

# %%
iqr=q3-q1

# %%
hl=q1+1.5*iqr
ll=q1-1.5*iqr

# %%
w1=df[(df["horsepower"]<hl) &(df["horsepower"]>ll)]

# %%
sns.boxenplot(y="horsepower",data=w1)
# Out:
# <Axes: ylabel='horsepower'>
